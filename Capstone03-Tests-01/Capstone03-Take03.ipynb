# %%
import pandas as pd

# %%
import os
os.chdir('/Users/mauroaz/Documents/Git_General/capstone_03')

# %%
Olist_06 = pd.read_csv('data-Olist-6_months.csv')

# %%
Olist_06.shape
# Out:
# (96095, 6)

# %%
Olist_06.head()
# Out:
#                  customer_unique_id     date_first_order  year_first_order  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2  2018-05-10 10:56:27              2018
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  2018-05-07 11:11:27              2018
# 2  0000f46a3911fa3c0805444483337064  2017-03-10 21:05:03              2017
# 3  0000f6ccb0745a6a4b88665a16c9f078  2017-10-12 20:29:41              2017
# 4  0004aac84e0df4da2b147fca70cf8255  2017-11-14 19:45:42              2017
#
#    month_first_order  total_orders_first_6_months  total_paid_first_6_months
# 0                  5                            1                     141.90
# 1                  5                            1                      27.19
# 2                  3                            1                      86.22
# 3                 10                            1                      43.62
# 4                 11                            1                     196.89

# %%
Olist_06.dtypes
# Out:
# customer_unique_id              object
# date_first_order                object
# year_first_order                 int64
# month_first_order                int64
# total_orders_first_6_months      int64
# total_paid_first_6_months      float64
# dtype: object

# %%
import statsmodels.formula.api as smf
linear_model = smf.ols(formula='total_paid_first_6_months ~ month_first_order + total_orders_first_6_months', data=Olist_06)
fitted_model = linear_model.fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     total_paid_first_6_months   R-squared:                       0.013
# Model:                                   OLS   Adj. R-squared:                  0.013
# Method:                        Least Squares   F-statistic:                     633.1
# Date:                       Thu, 05 Dec 2019   Prob (F-statistic):          6.81e-274
# Time:                               12:31:01   Log-Likelihood:            -6.5859e+05
# No. Observations:                      96095   AIC:                         1.317e+06
# Df Residuals:                          96092   BIC:                         1.317e+06
# Df Model:                                  2
# Covariance Type:                   nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
Olist_New = pd.read_csv('/Users/mauroaz/Documents/Git_General/capstone_03/data-Olist-6_months_TEST_01.csv')

# %%
Olist_New.dtypes
Olist_New.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96095 entries, 0 to 96094
# Data columns (total 8 columns):
# customer_unique_id             96095 non-null object
# date_first_order               96095 non-null object
# year_first_order               96095 non-null int64
# month_first_order              96095 non-null int64
# total_orders_first_6_months    96095 non-null int64
# total_paid_first_6_months      96095 non-null float64
# customer_state                 96095 non-null object
# customer_city                  96095 non-null object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 5.9+ MB

# %%
import statsmodels.formula.api as smf
linear_model = smf.ols(formula='total_paid_first_6_months ~ C(month_first_order) + total_orders_first_6_months + C(customer_state) + C(customer_city)', data=Olist_New)
fitted_model = linear_model.fit()
fitted_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     total_paid_first_6_months   R-squared:                       0.059
# Model:                                   OLS   Adj. R-squared:                  0.017
# Method:                        Least Squares   F-statistic:                     1.411
# Date:                       Thu, 05 Dec 2019   Prob (F-statistic):           8.80e-59
# Time:                               16:31:46   Log-Likelihood:            -6.5628e+05
# No. Observations:                      96095   AIC:                         1.321e+06
# Df Residuals:                          91988   BIC:                         1.360e+06
# Df Model:                               4106
# Covariance Type:                   nonrobust
# ...
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
Olist_New.isnull().values.any()
# Out:
# False
